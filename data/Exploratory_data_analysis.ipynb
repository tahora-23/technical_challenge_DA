# %% [markdown]
# ## Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('measurements.csv')

df2 = pd.read_excel('measurements2.xlsx')

# %%
df.head()
# Out:
#   distance consume  speed temp_inside  temp_outside specials gas_type  AC  \
# 0       28       5     26        21,5            12      NaN      E10   0
# 1       12     4,2     30        21,5            13      NaN      E10   0
# 2     11,2     5,5     38        21,5            15      NaN      E10   0
# 3     12,9     3,9     36        21,5            14      NaN      E10   0
# 4     18,5     4,5     46        21,5            15      NaN      E10   0
#
#    rain  sun refill liters refill gas
# 0     0    0            45        E10
# 1     0    0           NaN        NaN
# 2     0    0           NaN        NaN
# 3     0    0           NaN        NaN
# 4     0    0           NaN        NaN

# %%
df2.head()
# Out:
#    distance  consume  speed  temp_inside  temp_outside specials gas_type  AC  \
# 0      28.0      5.0     26         21.5            12      NaN      E10   0
# 1      12.0      4.2     30         21.5            13      NaN      E10   0
# 2      11.2      5.5     38         21.5            15      NaN      E10   0
# 3      12.9      3.9     36         21.5            14      NaN      E10   0
# 4      18.5      4.5     46         21.5            15      NaN      E10   0
#
#    rain  sun  refill liters refill gas
# 0     0    0           45.0        E10
# 1     0    0            NaN        NaN
# 2     0    0            NaN        NaN
# 3     0    0            NaN        NaN
# 4     0    0            NaN        NaN

# %%
data = pd.concat([df,df2], axis=0)

# %%
data
# Out:
#     distance consume  speed temp_inside  temp_outside specials gas_type  AC  \
# 0         28       5     26        21,5            12      NaN      E10   0
# 1         12     4,2     30        21,5            13      NaN      E10   0
# 2       11,2     5,5     38        21,5            15      NaN      E10   0
# 3       12,9     3,9     36        21,5            14      NaN      E10   0
# 4       18,5     4,5     46        21,5            15      NaN      E10   0
# ..       ...     ...    ...         ...           ...      ...      ...  ..
# 383     16.0     3.7     39        24.5            18      NaN     SP98   0
# 384     16.1     4.3     38        25.0            31       AC     SP98   1
# 385     16.0     3.8     45        25.0            19      NaN     SP98   0
# 386     15.4     4.6     42        25.0            31       AC     SP98   1
# 387     14.7     5.0     25        25.0            30       AC     SP98   1
#
#      rain  sun refill liters refill gas
# 0       0    0            45        E10
# 1       0    0           NaN        NaN
# 2       0    0           NaN        NaN
# 3       0    0           NaN        NaN
# 4       0    0           NaN        NaN
# ..    ...  ...           ...        ...
# 383     0    0           NaN        NaN
# 384     0    0           NaN        NaN
# 385     0    0           NaN        NaN
# 386     0    0           NaN        NaN
# 387     0    0           NaN        NaN
#
# [776 rows x 12 columns]

# %%
display(data.shape)
# Out:
# (776, 12)

# %% [markdown]
# #### Making assumption about the data as information about columns were not provided

# %% [markdown]
# * distance is measured in KM
# * 'consume' is Liter per 100 kM
# * Speed is lenght of time per trip per minutes
# * temp is in Celcius
# * AC, Rain and Sun are weather condition of trip

# %%
#Checking the null values
null_values = data.isnull().sum()

# %%
null_values
# Out:
# distance           0
# consume            0
# speed              0
# temp_inside       24
# temp_outside       0
# specials         590
# gas_type           0
# AC                 0
# rain               0
# sun                0
# refill liters    750
# refill gas       750
# dtype: int64

# %%
#Droping the columns with highest null values

columns_to_drop = ['specials','refill liters','refill gas']

data = data.drop(columns = columns_to_drop, axis=1)

print(data)
# Out:
#     distance consume  speed temp_inside  temp_outside gas_type  AC  rain  sun
# 0         28       5     26        21,5            12      E10   0     0    0
# 1         12     4,2     30        21,5            13      E10   0     0    0
# 2       11,2     5,5     38        21,5            15      E10   0     0    0
# 3       12,9     3,9     36        21,5            14      E10   0     0    0
# 4       18,5     4,5     46        21,5            15      E10   0     0    0
# ..       ...     ...    ...         ...           ...      ...  ..   ...  ...
# 383     16.0     3.7     39        24.5            18     SP98   0     0    0
# 384     16.1     4.3     38        25.0            31     SP98   1     0    0
# 385     16.0     3.8     45        25.0            19     SP98   0     0    0
# 386     15.4     4.6     42        25.0            31     SP98   1     0    0
# 387     14.7     5.0     25        25.0            30     SP98   1     0    0
#
# [776 rows x 9 columns]

# %%
data.dtypes
# Out:
# distance        object
# consume         object
# speed            int64
# temp_inside     object
# temp_outside     int64
# gas_type        object
# AC               int64
# rain             int64
# sun              int64
# dtype: object

# %%
#Converting the type to float (numerical) and replacing the comma with dot for decimals

data['temp_inside'] = data['temp_inside'].replace(',', '.', regex= True).astype(float)
data['distance'] = data['distance'].str.replace(',', '.',regex= True).astype(float)
data['consume'] = data['consume'].str.replace(',', '.',regex= True).astype(float)

# %%
#fill the null values in distance with mean of the column
mean_distance = data['distance'].mean()
data['distance'].fillna( mean_distance, inplace =True)

# %%
#fill the null values in consume with mean of the column
mean_consume = data['consume'].mean()
data['consume'].fillna(mean_consume, inplace =True)

# %%
#fill the null values in temp_inside with mode of the column

mode_temp_inside= data['temp_inside'].mode()
data['temp_inside'].fillna( mode_temp_inside[0], inplace =True)

# %%
null_values = data.isnull().sum()
null_values
# Out:
# distance        0
# consume         0
# speed           0
# temp_inside     0
# temp_outside    0
# gas_type        0
# AC              0
# rain            0
# sun             0
# dtype: int64

# %% [markdown]
# #### Creating new Features

# %%
data['temp_diff'] = data.temp_inside - data.temp_outside

# %%
data['fuel_used'] = data.distance * data.consume/100

# %% [markdown]
# **Current price of fuel in Germnay**
#
# E10  1,86 €
#
# SP98 1,913 €

# %%
data['cost_of_trip'] = np.where(data.gas_type == 'E10', data.fuel_used*1.866, data.fuel_used* 1.913).round(3)

# %%
data
# Out:
#       distance   consume  speed  temp_inside  temp_outside gas_type  AC  rain  \
# 0    28.000000  5.000000     26         21.5            12      E10   0     0
# 1    12.000000  4.200000     30         21.5            13      E10   0     0
# 2    11.200000  5.500000     38         21.5            15      E10   0     0
# 3    12.900000  3.900000     36         21.5            14      E10   0     0
# 4    18.500000  4.500000     46         21.5            15      E10   0     0
# ..         ...       ...    ...          ...           ...      ...  ..   ...
# 383  19.652835  4.912371     39         24.5            18     SP98   0     0
# 384  19.652835  4.912371     38         25.0            31     SP98   1     0
# 385  19.652835  4.912371     45         25.0            19     SP98   0     0
# 386  19.652835  4.912371     42         25.0            31     SP98   1     0
# 387  19.652835  4.912371     25         25.0            30     SP98   1     0
#
#      sun  temp_diff  fuel_used  cost_of_trip
# 0      0        9.5    1.40000         2.612
# 1      0        8.5    0.50400         0.940
# 2      0        6.5    0.61600         1.149
# 3      0        7.5    0.50310         0.939
# 4      0        6.5    0.83250         1.553
# ..   ...        ...        ...           ...
# 383    0        6.5    0.96542         1.847
# 384    0       -6.0    0.96542         1.847
# 385    0        6.0    0.96542         1.847
# 386    0       -6.0    0.96542         1.847
# 387    0       -5.0    0.96542         1.847
#
# [776 rows x 12 columns]

# %% [markdown]
# **Converting Speed to decimal of an hour**

# %%
data['trip_in_hour'] = data.speed/60

# %%
data['avg_speed'] = data['distance']/data['trip_in_hour']

# %%
data = data.drop(['speed'], axis = 1)

# %%
# seperating the numerical and categorical
data.dtypes
numerical = data.select_dtypes(include = np.number)
categorical = data.select_dtypes(object)

# %%
numerical.describe().T
# Out:
#               count       mean        std        min        25%        50%  \
# distance      776.0  19.652835  16.018237   1.300000  14.650000  19.652835
# consume       776.0   4.912371   0.730091   3.300000   4.700000   4.912371
# temp_inside   776.0  21.916237   0.996805  19.000000  21.500000  22.000000
# temp_outside  776.0  11.358247   6.987030  -5.000000   7.000000  10.000000
# AC            776.0   0.077320   0.267270   0.000000   0.000000   0.000000
# rain          776.0   0.123711   0.329464   0.000000   0.000000   0.000000
# sun           776.0   0.082474   0.275263   0.000000   0.000000   0.000000
# temp_diff     776.0  10.557990   6.695775  -8.000000   6.375000  11.500000
# fuel_used     776.0   0.950357   0.788743   0.120000   0.680600   0.965420
# cost_of_trip  776.0   1.798858   1.497028   0.224000   1.286500   1.801000
# trip_in_hour  776.0   0.698797   0.226496   0.233333   0.545833   0.675000
# avg_speed     776.0  28.962815  15.425377   3.714286  19.985934  26.203780
#
#                     75%       max
# distance      19.652835  216.1000
# consume        4.912371   12.2000
# temp_inside   22.500000   25.5000
# temp_outside  16.000000   31.0000
# AC             0.000000    1.0000
# rain           0.000000    1.0000
# sun            0.000000    1.0000
# temp_diff     14.625000   26.0000
# fuel_used      0.965420   11.4533
# cost_of_trip   1.847000   21.9100
# trip_in_hour   0.833333    1.5000
# avg_speed     34.681474  158.2500

# %%
data.to_csv('data_clean.csv', index= False)
